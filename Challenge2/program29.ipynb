# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to Count Words in a Sentence

#take the input from the user
sentence = input("Enter a sentence: ")
words = sentence.split()  # Splits by spaces
print("Word count:", len(words))
# Out:
# Enter a sentence: my name is akshay
# Word count: 4
