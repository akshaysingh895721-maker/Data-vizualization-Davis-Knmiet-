# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to calculate the bonuses
# Input the salary
salary = float(input("Enter salary: "))

# Calculate bonus (7% of salary)
bonus = salary * 0.07

# print the output of the program
print("Bonus =", int(bonus))
# Out:
# Enter salary: 50000
# Bonus = 3500
