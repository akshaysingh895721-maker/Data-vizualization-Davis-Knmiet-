# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program to remove the space from string


#take the input from the user
text = input("Enter a string: ")
result = ""

for ch in text:
    if ch != " ":
        result += ch

print("Output:", result)
# Out:
# Enter a string: a k s h a y
# Output: akshay
