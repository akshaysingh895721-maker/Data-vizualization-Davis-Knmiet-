# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program to check if a number satisfies this condition.
num = int(input("Enter a number: "))

#apply the condition
if num % 3 == 0 and num % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
# Enter a number: 15
# Yes
