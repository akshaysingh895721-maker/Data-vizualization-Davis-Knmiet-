# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to find the maximum number

#take the input from the user
nums = list(map(int, input("Enter numbers separated by space: ").split()))

max_num = nums[0]

#apply the condition
for num in nums:
    if num > max_num:3
max_num = num

print("Maximum =", max_num)
# Out:
# Enter numbers separated by space: 3 4 6
# Maximum = 6
