# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# program to check string is polindrom or not


#take the input from the user
text = input("Enter a string: ").lower()

if text == text[::-1]:
    print("Yes")
else:
    print("No")
# Out:
# Enter a string: akshay
# No
