# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program calculate the ticket price bassed on day

#take the input from the user
day = input("Enter day: ").lower()

if day == "sunday":
    print(200)
elif day == "saturday":
    print(150)
else:
    print(100)
# Out:
# Enter day: sunday
# 200
