# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to replace vowel with *

#take the input from the user
text = input("Enter a string: ").lower()
vowels = "aeiou"
result = ""

for ch in text:
    if ch in vowels:
        result += "*"
    else:
        result += ch

print("Output:", result)
# Out:
# Enter a string: akshay
# Output: *ksh*y
