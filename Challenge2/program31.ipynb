# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to remove the duplicate number

# take the input from the user
lst = list(map(int, input("Enter numbers separated by space: ").split()))
unique_list = []

for item in lst:
    if item not in unique_list:
        unique_list.append(item)

print("List without duplicates:", unique_list)
# Out:
# Enter numbers separated by space: 2 2 3 4
# List without duplicates: [2, 3, 4]
