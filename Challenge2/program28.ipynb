# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to Check if Two Strings Are Anagrams

#take the input from the user
str1 = input("Enter first string: ").replace(" ", "").lower()
str2 = input("Enter second string: ").replace(" ", "").lower()

# Check if sorted characters match
if sorted(str1) == sorted(str2):
    print(True)
else:
    print(False)
# Out:
# Enter first string: akshay
# Enter second string: singh
# False
