# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to check leap year or not

#take the input from the user
year = int(input("Enter year: "))

#apply the condition of leap year
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")  #print the output
else:
    print("Not a Leap Year")
# Out:
# Enter year: 2024
# Leap Year
