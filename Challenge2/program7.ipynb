# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Challenge2/program7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to check character is vowel or not

#program to take input from the user
ch = input("Enter a character: ").lower()

if ch in ['a', 'e', 'i', 'o', 'u']:
    print("Vowel")
else:
    print("Not a Vowel")
# Out:
# Enter a character: a
# Vowel
