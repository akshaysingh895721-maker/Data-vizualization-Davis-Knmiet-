# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Progr11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to Calculate Discount

def calculate_discount(price, discount):
    return price - (price * discount / 100)

price = float(input("Enter price: "))
discount = float(input("Enter discount %: "))

print("Final price:", calculate_discount(price, discount))
# Out:
# Enter price: 500
# Enter discount %: 5
# Final price: 475.0
