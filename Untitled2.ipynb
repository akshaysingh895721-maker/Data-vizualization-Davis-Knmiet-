# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function to identify odd or even number
def check_odd_even(num):
    # Check if the number is divisible by 2
    if num % 2 == 0:
        # If remainder is 0, number is even
        return "Even"
    else:
        # Otherwise, number is odd
        return "Odd"

# Taking input from user
number = int(input("Enter a number: "))

# Calling the function and storing result
result = check_odd_even(number)

# Printing the result
print("The number is:", result)
