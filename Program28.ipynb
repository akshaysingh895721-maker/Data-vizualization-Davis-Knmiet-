# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Program28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Program to calculate the electricity bill

#taking the input from the user
units = int(input("Enter units: "))

bill = units*5 if units<=100 else (100*5 + (units-100)*7 if units<=200 else 100*5 + 100*7 + (units-200)*10)
print("Total bill:", bill)
# Out:
# Enter units: 200
# Total bill: 1200
