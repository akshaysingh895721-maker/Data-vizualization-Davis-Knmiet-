# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Program26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program for calculating total bill after discount

#taking the input from the user
price = float(input("Enter price: "))
discount = float(input("Enter discount %: "))

discount_amount = price * discount / 100
final_price = price - discount_amount

print("Final price:", final_price)
# Out:
# Enter price: 500
# Enter discount %: 2
# Final price: 490.0
