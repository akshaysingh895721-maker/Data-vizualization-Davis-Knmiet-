# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Classwork/program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json

url = "https://raw.githubusercontent.com/akshaysingh895721-maker/Lab-Work-Data-Visualization-/refs/heads/main/prog%201.ipynb"

data = requests.get(url).json()

# cells me se code extract karo
for cell in data['cells']:
    if cell['cell_type'] == 'code':
        print("".join(cell['source']))
        print("\n------\n")
# Out:
# # Input the list
# numbers = [1, 2, 3, 2, 4, 5, 1]
#
# duplicates = []
# data = set()
#
# for num in numbers:
#     if num in data:
#         if num not in duplicates:
#             duplicates.append(num)
#     else:
#         data.add(num)
#
# print("Duplicate elements:", duplicates)
#
# ------
