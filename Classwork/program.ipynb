# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Classwork/program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
variable = numpy.array(list_or_tupple)

import numpy as np


#create array
numbers = np.array([20,30,40,90])
print(numbers)


import numpy as np
num = np.array([20,30,40.2.5])
print(num)

import numpy as np

#creating array
numbers = numpy



import numpy as np
data = np.array([45,'python',56])
print(data)


import numpy as np
data = np.array([45,56,89,90,29])
print(data)



import numpy as np
x = np.arange(10,100,5)
print(x)
