# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/Data-vizualization-Davis-Knmiet-/blob/main/Classwork/program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program for writing data into the list

files = open("firstfile.txt","w")

#blank list of sentence
sentence = []

#writing five sentence into the file
print("enter any five sentence")
for x in range(5):

    #input of data from user
    sentence = input()
    #inserting the data into the list

  sentence.append(sentence)
  print("_____________________________________________________")

#__________________________________________________________
  writing data into the file

filev.writlines(sentences)

print("data successfully written")

#closing the file
filev.close()
