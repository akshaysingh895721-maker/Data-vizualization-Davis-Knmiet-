# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaysingh895721-maker/pythonprogram/blob/main/Program24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program to print all even number list

#taking the input from the user
n = int(input("Enter N: "))

even_numbers = list(filter(lambda x: x%2==0, range(1, n+1)))
print(even_numbers)
# Out:
# Enter N: 10
# [2, 4, 6, 8, 10]
